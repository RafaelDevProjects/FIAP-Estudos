# %% [markdown]
# # **FUNÇÕES**

# %%
from sympy import *

# %%
from sympy.plotting import *

# %%
x = Symbol('x')

# %% [markdown]
# # **FUNÇÕES LOGARÍTMICA**

# %%
plot(log(x, 1/4), (x,-1,6));

# %%
plot(log(x, 2), (x,-1,8));

# %%
plot(log(x, 1/2), (x,-2,8));

# %% [markdown]
# ### **Função Modular**

# %%
plot(abs(2*x),(x,-2,2));

# %%
plot(abs(3*x-2), (x,-2,3));

# %%
plot(x*abs(x), (x,-2,2));
